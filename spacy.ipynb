# %% [markdown]
# <a href="https://colab.research.google.com/github/bavisetti129/phani/blob/master/spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Spacy Open source lierary, install spacy
# !python3 -m spacy download en_core_web_md
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 95.4MB 69.8MB/s
# ...
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.1.0-cp36-none-any.whl size=97126236 sha256=e9b6630f4bed7a11e3baff8b6a500a89e364f498d0e88512a1741ba53e781247
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3y7p4pkv/wheels/c1/2c/5f/fd7f3ec336bf97b0809c86264d2831c5dfb00fc2e239d1bb01
# Successfully built en-core-web-md
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
nlp=spacy.load("en_core_web_sm")#pretrained model
doc=nlp("Apple is looking at buying UK startup for $1 billiin")
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Apple PROPN nsubj
# is VERB aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# UK PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM nmod
# 1 NUM nummod
# billiin NOUN pobj

# %%
#tokenization
import spacy
nlp=spacy.load("en_core_web_sm")
doc=nlp("Apple is looking at buying UK startup for $1 billiin")
for token in doc:
  print(token.text)
# Out:
# Apple
# is
# looking
# at
# buying
# UK
# startup
# for
# $
# 1
# billiin

# %%
#POS parts of speach
import spacy
from spacy import displacy
nlp=spacy.load("en_core_web_sm")
doc=nlp("Apple is looking at buying UK startup for $1 billiin")
#displacy.serve(doc,style="dep")
for token in doc:
  print(token.text,token.lemma_,token.pos_,token.tag_,token.dep_,token.shape_,token.is_alpha,token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be VERB VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# UK UK PROPN NNP compound XX True False
# startup startup NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ nmod $ False False
# 1 1 NUM CD nummod d False False
# billiin billiin NOUN NN pobj xxxx True False

# %%
#visualizers
import spacy
from spacy import displacy
nlp=spacy.load("en_core_web_sm")
doc=nlp("this is a sentence.")
displacy.render(doc,style='dep',jupyter=True,options={'distance':90})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cbf16600bd17499fb65e1936ef3c5e95-0" class="displacy" width="410" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">a</tspan>
# ...

# %%
#named entity recognition
import spacy
from spacy import displacy
nlp=spacy.load("en_core_web_sm")
text="""In ancient Rome, some neighbors live in three adjacent houses. In the center is the house of Senex, who lives there with wife Domina, son Hero, and several slaves, including head slave Hysterium and the musical's main character Pseudolus. A slave belonging to Hero, Pseudolus wishes to buy, win, or steal his freedom. One of the neighboring houses is owned by Marcus Lycus, who is a buyer and seller of beautiful women; the other belongs to the ancient Erronius, who is abroad searching for his long-lost children (stolen in infancy by pirates). One day, Senex and Domina go on a trip and leave Pseudolus in charge of Hero. Hero confides in Pseudolus that he is in love with the lovely Philia, one of the courtesans in the House of Lycus (albeit still a virgin)."""
doc=nlp(text)
sentence_spans=list(doc.sents)
displacy.render(doc,style='dep',jupyter=True,options={'distance':90})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7af3442f47e746e7b2bc1cfa7ddcdfa4-0" class="displacy" width="12290" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">ancient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Rome,</tspan>
# ...

# %%
#named entity recognition
import spacy
import en_core_web_md
from spacy import displacy
nlp=spacy.load("en_core_web_sm")
doc=nlp("Microsoft is looking at buying Uk startup for $1 billion")
for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)
  displacy.render(doc,style='ent',jupyter=True,options={'distance':90})
# Out:
# Microsoft 0 9 ORG
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Uk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# ...

# %%
#similary
import spacy
import en_core_web_md
nlp=spacy.load("en_core_web_md")
tokens=nlp("dog cat banana afskfsd")
for token in tokens:
  print(token.text,token.has_vector,token.vector_norm,token.is_oov)
# Out:
# dog True 7.0336733 False
# cat True 6.6808186 False
# banana True 6.700014 False
# afskfsd False 0.0 True

# %%
#similary f words
import spacy
nlp=spacy.load("en_core_web_md") #make sure to use larger model!
tokens=nlp("dog cat banana")
for token1 in tokens:
  for token2 in tokens:
    print(token1.text,token2.text,token1.similarity(token2))
# Out:
# dog dog 1.0
# dog cat 0.80168545
# dog banana 0.24327643
# cat dog 0.80168545
# cat cat 1.0
# cat banana 0.28154364
# banana dog 0.24327643
# banana cat 0.28154364
# banana banana 1.0

# %%
#hash strings
import spacy
nlp=spacy.load("en_core_web_sm")
doc=nlp("I love coffee")
for word in doc:
  lexeme=doc.vocab[word.text]
  print(lexeme.text,lexeme.orth,lexeme.shape_,lexeme.prefix_,lexeme.suffix_,lexeme.is_alpha,lexeme.is_digit,lexeme.is_title,lexeme.lang_)
# Out:
# I 4690420944186131903 X I I True False True en
# love 3702023516439754181 xxxx l ove True False False en
# coffee 3197928453018144401 xxxx c fee True False False en
